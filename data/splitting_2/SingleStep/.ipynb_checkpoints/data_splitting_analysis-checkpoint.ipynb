# %%
import pandas as pd
import numpy as np
import rdkit
from rdkit import Chem

# %%
# !pip install rdkit

# %% [markdown]
# # Data loading

# %%
raw_df1 = pd.read_csv('/scratch/yw5806/Multistep_final/data/splitting_2/rxn_train.csv')
raw_df2 = pd.read_csv('/scratch/yw5806/Multistep_final/data/splitting_2/rxn_vali.csv')
raw_df3 = pd.read_csv('/scratch/yw5806/Multistep_final/data/splitting_2/rxn_test.csv')

raw_df3.describe()
raw_df3.info()
raw_df3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   #                    137 non-null    int64
#  1   Method               137 non-null    object
#  2   Reagent_A            137 non-null    object
#  3   Reagent_B            137 non-null    object
#  4   Reagent_C            137 non-null    object
#  5   Product              137 non-null    object
#  6   Yield                137 non-null    int64
#  7   mg                   137 non-null    float64
#  8   step_1_reagents      137 non-null    object
#  9   step_2_reagents      137 non-null    object
#  10  step_3_reagents      104 non-null    object
#  11  step_1_intermediate  137 non-null    object
#  12  step_2_intermediate  104 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 14.0+ KB
#       # Method                                Reagent_A             Reagent_B  \
# 0   199      E               Cl.[N-]=[N+]=NC[C@H]1CCCN1     CC(=CC(=O)O)C1CC1
# 1  1294      C           CC(C)(C)OC(=O)N1CCc2ccccc2C1CN  O=C(O)c1cccc2ccccc12
# 2   384      B  CC(C)(C)OC(=O)N[C@@H]1CNC[C@H]1C(F)(F)F         O=C(O)CC1CCC1
# 3   544      A                  CC(C)(C)OC(=O)N1CCCC1CN      COc1ccccc1C(=O)O
# 4   362      E          Cl.[N-]=[N+]=N[C@H]1C[C@H](N)C1  O=C(O)COc1ccc(Cl)cc1
#
#                  Reagent_C                                            Product  \
# 0            C#Cc1cn[nH]c1  CC(=CC(=O)N1CCC[C@@H]1Cn1cc(-c2cn[nH]c2)nn1)C1CC1
# 1            O=C1NCCN1CCCl     O=C(NCC1c2ccccc2CCN1CCN1CCNC1=O)c1cccc2ccccc12
# 2          COCCc1nsc(Cl)n1  COCCc1nsc(N[C@@H]2CN(C(=O)CC3CCC3)C[C@H]2C(F)(...
# 3     CN1CCC(C(=O)O)CC1.Cl           COc1ccccc1C(=O)NCC1CCCN1C(=O)C1CCN(C)CC1
# 4  C#CCOc1cccc(C(F)(F)F)n1  O=C(COc1ccc(Cl)cc1)NC1CC(n2cc(COc3cccc(C(F)(F)...
#
#    Yield    mg                                    step_1_reagents  \
# 0     68  45.1  CCN(C(C)C)C(C)C.CN(C)C=O.CN(C)C(=[N+](C)C)N1C2...
# 1     11   5.2  CCN(C(C)C)C(C)C.CS(C)=O.CN(C)C(=[N+](C)C)N1C2=...
# 2     58  19.4  CCN(C(C)C)C(C)C.CS(C)=O.CN(C)C(=[N+](C)C)N1C2=...
# 3     50  23.3  CCN(C(C)C)C(C)C.CS(C)=O.CN(C)C(=[N+](C)C)N1C2=...
# 4     59  27.5  CCN(C(C)C)C(C)C.CN(C)C=O.CN(C)C(=[N+](C)C)N1C2...
#
#                                 step_2_reagents  \
# 0  CCN(C(C)C)C(C)C.CC(=O)[O-].CC(=O)[O-].[Cu+2]
# 1       CC(C)[SiH](C(C)C)C(C)C.O.O=C(O)C(F)(F)F
# 2       CC(C)[SiH](C(C)C)C(C)C.O.O=C(O)C(F)(F)F
# 3       CC(C)[SiH](C(C)C)C(C)C.O.O=C(O)C(F)(F)F
# 4  CCN(C(C)C)C(C)C.CC(=O)[O-].CC(=O)[O-].[Cu+2]
#
#                                      step_3_reagents  \
# 0                                                NaN
# 1                           CCN(C(C)C)C(C)C.CN(C)C=O
# 2                         CCN(C(C)C)C(C)C.CN1CCCC1=O
# 3  CCN(C(C)C)C(C)C.CS(C)=O.CN(C)C(=[N+](C)C)N1C2=...
# 4                                                NaN
#
#                                  step_1_intermediate  \
# 0           CC(=CC(=O)N1CCC[C@@H]1CN=[N+]=[N-])C1CC1
# 1  CC(C)(C)OC(=O)N1CCc2ccccc2C1CNC(=O)c1cccc2ccccc12
# 2  CC(C)(C)OC(=O)N[C@@H]1CN(C(=O)CC2CCC2)C[C@H]1C...
# 3             COc1ccccc1C(=O)NCC1CCCN1C(=O)OC(C)(C)C
# 4    [N-]=[N+]=N[C@H]1C[C@H](NC(=O)COc2ccc(Cl)cc2)C1
#
#                        step_2_intermediate
# 0                                      NaN
# 1      O=C(NCC1NCCc2ccccc21)c1cccc2ccccc12
# 2  N[C@@H]1CN(C(=O)CC2CCC2)C[C@H]1C(F)(F)F
# 3                 COc1ccccc1C(=O)NCC1CCCN1
# 4                                      NaN

# %%
train_source = open('train.source', 'w')
train_target = open('train.target', 'w')

val_source = open('val.source', 'w')
val_target = open('val.target', 'w')

test_source = open('test.source', 'w')
test_target = open('test.target', 'w')

# %% [markdown]
# # Write input files

# %%
for i, row in raw_df1.iterrows():

    if row["Method"] == "E":
        #print(i)
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])
        step2_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        interm_1 = Chem.CanonSmiles(row['step_1_intermediate'])
        product = Chem.CanonSmiles(row['Product'])

        print(step1_reactants + "." + step_1_reagents + ">>" , file=train_source)
        print(interm_1 + "."  + step2_reactants + "." + step_2_reagents  + ">>" , file=train_source)

        print(interm_1, file=train_target)
        print(product, file=train_target)
    else:
        # for other methods, step2 is deprotection and there's no reactants involved.
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])
        interm_1 = Chem.CanonSmiles(row['step_1_intermediate'])

        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        interm_2 = Chem.CanonSmiles(row['step_2_intermediate'])
        step3_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_3_reagents = Chem.CanonSmiles(row['step_3_reagents'])
        product = Chem.CanonSmiles(row['Product'])
        print(step1_reactants + "." + step_1_reagents  + ">>" , file=train_source)
        print(interm_1 + "." + step_2_reagents  + ">>" , file=train_source)
        print(interm_2 + "." + step3_reactants + "." + step_3_reagents + ">>" , file=train_source)

        print(interm_1, file=train_target)
        print(interm_2, file=train_target)
        print(product, file=train_target)

# %%
for i, row in raw_df2.iterrows():
    if row["Method"] == "E":
        #print(i)
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])
        step2_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        interm_1 = Chem.CanonSmiles(row['step_1_intermediate'])
        product = Chem.CanonSmiles(row['Product'])
        print(step1_reactants + "." + step_1_reagents + ">>" , file=val_source)
        print(interm_1 + "."  + step2_reactants + "." + step_2_reagents  + ">>" , file=val_source)

        print(interm_1, file=val_target)
        print(product, file=val_target)

    else:
        # for other methods, step2 is deprotection and there's no reactants involved.
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])
        interm_1 = Chem.CanonSmiles(row['step_1_intermediate'])

        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        interm_2 = Chem.CanonSmiles(row['step_2_intermediate'])
        step3_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_3_reagents = Chem.CanonSmiles(row['step_3_reagents'])
        product = Chem.CanonSmiles(row['Product'])
        print(step1_reactants + "." + step_1_reagents  + ">>" , file=val_source)
        print(interm_1 + "." + step_2_reagents  + ">>" , file=val_source)
        print(interm_2 + "." + step3_reactants + "." + step_3_reagents + ">>" , file=val_source)

        print(interm_1, file=val_target)
        print(interm_2, file=val_target)
        print(product, file=val_target)

# %%
for i, row in raw_df3.iterrows():
    if row["Method"] == "E":
        #print(i)
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])
        step2_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        interm_1 = Chem.CanonSmiles(row['step_1_intermediate'])
        product = Chem.CanonSmiles(row['Product'])

        print(step1_reactants + "." + step_1_reagents + ">>" , file=test_source)
        print(interm_1 + "."  + step2_reactants + "." + step_2_reagents  + ">>" , file=test_source)

        print(interm_1, file=test_target)
        print(product, file=test_target)


    else:
        # for other methods, step2 is deprotection and there's no reactants involved.
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])
        interm_1 = Chem.CanonSmiles(row['step_1_intermediate'])

        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        interm_2 = Chem.CanonSmiles(row['step_2_intermediate'])
        step3_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_3_reagents = Chem.CanonSmiles(row['step_3_reagents'])
        product = Chem.CanonSmiles(row['Product'])
        print(step1_reactants + "." + step_1_reagents  + ">>" , file=test_source)
        print(interm_1 + "." + step_2_reagents  + ">>" , file=test_source)
        print(interm_2 + "." + step3_reactants + "." + step_3_reagents + ">>" , file=test_source)

        print(interm_1, file=test_target)
        print(interm_2, file=test_target)
        print(product, file=test_target)

# %%
train_source.close()
train_target.close()
val_source.close()
val_target.close()
test_source.close()
test_target.close()

# %%
print(len(train_source))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 print(len(train_source))
#
# TypeError: object of type '_io.TextIOWrapper' has no len()

# %% [markdown]
# ## The reagents are shuffled.
