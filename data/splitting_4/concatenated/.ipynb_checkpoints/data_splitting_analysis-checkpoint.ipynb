# %%
import pandas as pd
import numpy as np
import rdkit
from rdkit import Chem

# %% [markdown]
# # Data loading

# %%
raw_df1 = pd.read_csv('/scratch/yw5806/Multistep_final/data/splitting_4/rxn_train.csv')
raw_df2 = pd.read_csv('/scratch/yw5806/Multistep_final/data/splitting_4/rxn_vali.csv')
raw_df3 = pd.read_csv('/scratch/yw5806/Multistep_final/data/splitting_4/rxn_test.csv')

raw_df3.describe()
raw_df3.info()
raw_df3.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   #                    137 non-null    int64
#  1   Method               137 non-null    object
#  2   Reagent_A            137 non-null    object
#  3   Reagent_B            137 non-null    object
#  4   Reagent_C            137 non-null    object
#  5   Product              137 non-null    object
#  6   Yield                137 non-null    int64
#  7   mg                   137 non-null    float64
#  8   step_1_reagents      137 non-null    object
#  9   step_2_reagents      137 non-null    object
#  10  step_3_reagents      100 non-null    object
#  11  step_1_intermediate  137 non-null    object
#  12  step_2_intermediate  100 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 14.0+ KB
#       # Method                               Reagent_A  \
# 0    96      B                CC(C)(C)OC(=O)NCC1CCCC1N
# 1  1040      D  CC(C)(C)OC(=O)NC[C@]12CCC[C@H]1CNC2.Cl
# 2   573      D         CC(C)(C)OC(=O)N1Cc2ccc(CN)cc2C1
# 3   754      E            [N-]=[N+]=NCc1ccc(C(=O)O)cc1
# 4   879      A            CC(C)(C)OC(=O)NC1CCCC2CNCC21
#
#                 Reagent_B             Reagent_C  \
# 0  NC(=O)c1cccc(C(=O)O)c1          Fc1cnc(F)nc1
# 1         Clc1ccc2nnnn2n1        Cn1cccc1C(=O)O
# 2               Fc1ncccn1  O=C(O)C1CCCC(F)(F)C1
# 3             Cc1ncsc1CCN   C#Cc1ccc2[nH]ccc2c1
# 4   Cl.O=C(O)c1cnc2n1CCC2              CCC(=O)O
#
#                                              Product  Yield    mg  \
# 0         NC(=O)c1cccc(C(=O)NC2CCCC2CNc2ncc(F)cn2)c1     80  37.5
# 1  Cn1cccc1C(=O)NC[C@]12CCC[C@H]1CN(c1ccc3nnnn3n1)C2     23  30.4
# 2       O=C(C1CCCC(F)(F)C1)N1Cc2ccc(CNc3ncccn3)cc2C1     48  22.3
# 3  Cc1ncsc1CCNC(=O)c1ccc(Cn2cc(-c3ccc4[nH]ccc4c3)...     37  12.4
# 4           CCC(=O)NC1CCCC2CN(C(=O)c3cnc4n3CCC4)CC21     31  14.3
#
#                                      step_1_reagents  \
# 0  CCN(C(C)C)C(C)C.CS(C)=O.CN(C)C(=[N+](C)C)N1C2=...
# 1                         CCN(C(C)C)C(C)C.CN1CCCC1=O
# 2                         CCN(C(C)C)C(C)C.CN1CCCC1=O
# 3  CCN(C(C)C)C(C)C.CN(C)C=O.CN(C)C(=[N+](C)C)N1C2...
# 4  CCN(C(C)C)C(C)C.CS(C)=O.CN(C)C(=[N+](C)C)N1C2=...
#
#                                 step_2_reagents  \
# 0       CC(C)[SiH](C(C)C)C(C)C.O.O=C(O)C(F)(F)F
# 1       CC(C)[SiH](C(C)C)C(C)C.O.O=C(O)C(F)(F)F
# 2       CC(C)[SiH](C(C)C)C(C)C.O.O=C(O)C(F)(F)F
# 3  CCN(C(C)C)C(C)C.CC(=O)[O-].CC(=O)[O-].[Cu+2]
# 4       CC(C)[SiH](C(C)C)C(C)C.O.O=C(O)C(F)(F)F
#
#                                      step_3_reagents  \
# 0                         CCN(C(C)C)C(C)C.CN1CCCC1=O
# 1  CCN(C(C)C)C(C)C.CS(C)=O.CN(C)C(=[N+](C)C)N1C2=...
# 2  CCN(C(C)C)C(C)C.CS(C)=O.CN(C)C(=[N+](C)C)N1C2=...
# 3                                                NaN
# 4  CCN(C(C)C)C(C)C.CS(C)=O.CN(C)C(=[N+](C)C)N1C2=...
#
#                                  step_1_intermediate  \
# 0      CC(C)(C)OC(=O)NCC1CCCC1NC(=O)c1cccc(C(N)=O)c1
# 1  CC(C)(C)OC(=O)NC[C@]12CCC[C@H]1CN(c1ccc3nnnn3n...
# 2            CC(C)(C)OC(=O)N1Cc2ccc(CNc3ncccn3)cc2C1
# 3             Cc1ncsc1CCNC(=O)c1ccc(CN=[N+]=[N-])cc1
# 4    CC(C)(C)OC(=O)NC1CCCC2CN(C(=O)c3cnc4n3CCC4)CC21
#
#                     step_2_intermediate
# 0       NCC1CCCC1NC(=O)c1cccc(C(N)=O)c1
# 1  NC[C@]12CCC[C@H]1CN(c1ccc3nnnn3n1)C2
# 2           c1cnc(NCc2ccc3c(c2)CNC3)nc1
# 3                                   NaN
# 4     NC1CCCC2CN(C(=O)c3cnc4n3CCC4)CC12

# %%
train_source = open('train.source', 'w')
train_target = open('train.target', 'w')

val_source = open('val.source', 'w')
val_target = open('val.target', 'w')

test_source = open('test.source', 'w')
test_target = open('test.target', 'w')

# %% [markdown]
# # Write input files

# %%
for i, row in raw_df1.iterrows():

    if row["Method"] == "E":
        #print(i)
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])
        step2_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        product = Chem.CanonSmiles(row['Product'])
        print(step1_reactants + "." + step_1_reagents + "//" + step2_reactants + "." + step_2_reagents, file=train_source)
        print(product, file=train_target)
    else:
        # for other methods, step2 is deprotection and there's no reactants involved.
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])

        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        step3_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_3_reagents = Chem.CanonSmiles(row['step_3_reagents'])
        product = Chem.CanonSmiles(row['Product'])        
        print(step1_reactants + "." + step_1_reagents + "//" + step_2_reagents + "//" + step3_reactants + "." + step_3_reagents, file=train_source)
        print(product, file=train_target)

# %%
for i, row in raw_df2.iterrows():
    if row["Method"] == "E":
        #print(i)
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])
        step2_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        product = Chem.CanonSmiles(row['Product'])
        print(step1_reactants + "." + step_1_reagents + "//" + step2_reactants + "." + step_2_reagents, file=val_source)
        print(product, file=val_target)
    else:
        # for other methods, step2 is deprotection and there's no reactants involved.
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])

        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        step3_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_3_reagents = Chem.CanonSmiles(row['step_3_reagents'])
        product = Chem.CanonSmiles(row['Product'])        
        print(step1_reactants + "." + step_1_reagents + "//" + step_2_reagents + "//" + step3_reactants + "." + step_3_reagents, file=val_source)
        print(product, file=val_target)

# %%
for i, row in raw_df3.iterrows():
    if row["Method"] == "E":
        #print(i)
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])
        step2_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        product = Chem.CanonSmiles(row['Product'])
        print(step1_reactants + "." + step_1_reagents + "//" + step2_reactants + "." + step_2_reagents, file=test_source)
        print(product, file=test_target)
    else:
        # for other methods, step2 is deprotection and there's no reactants involved.
        step1_reactants = Chem.CanonSmiles( ".".join( [row['Reagent_A'], row['Reagent_B']] ) )
        step_1_reagents = Chem.CanonSmiles(row['step_1_reagents'])

        step_2_reagents = Chem.CanonSmiles(row['step_2_reagents'])
        step3_reactants = Chem.CanonSmiles(row['Reagent_C'])
        step_3_reagents = Chem.CanonSmiles(row['step_3_reagents'])
        product = Chem.CanonSmiles(row['Product'])        
        print(step1_reactants + "." + step_1_reagents + "//" + step_2_reagents + "//" + step3_reactants + "." + step_3_reagents, file=test_source)
        print(product, file=test_target)

# %%
train_source.close()
train_target.close()
val_source.close()
val_target.close()
test_source.close()
test_target.close()
